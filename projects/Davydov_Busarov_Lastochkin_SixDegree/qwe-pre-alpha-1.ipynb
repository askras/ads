# %% [markdown]
# # Теория шести рукопожатий

# %% [markdown]
# ### Подготовили студенты ИУ10-46:

# %% [markdown]
# #### Ласточкин Иван
# #### Бусаров Никита
# #### Давыдов Егор

# %% [markdown]
# ## Историческая справка

# %% [markdown]
# Теория шести рукопожатий — социологическая теория, согласно которой любые два человека на Земле разделены не более чем пятью уровнями общих знакомых (и, соответственно, шестью уровнями связей). Формальная математическая формулировка теории — диаметр графа знакомств не превышает 6.

# %%
from IPython.display import Image
Image(filename='Desktop/7degree/qwe1.png')

# %% [markdown]
# Теория шести рукопожатий является интересным феноменом, который впервые был сформулирован в 1929 году венгерским писателем Фридрихом Каринти. Он выдвинул гипотезу о том, что каждый человек на планете может быть связан с другим любым человеком через цепочку знакомых длиной не более шести уровней. Однако, именно в 1967 году социолог Стэнли Милгрэм провел знаменитый эксперимент "Малый мир", который стал основой для дальнейших исследований и развития этой теории.
#
# Эксперимент Милгрэма состоял в том, чтобы выбрать случайного жителя Великобритании и передать ему письмо с просьбой доставить его определенному человеку, о котором изначально знали только его имя и место жительства. Для передачи письма участникам эксперимента разрешалось отправлять его только знакомым, которые могли быть связаны с искомым получателем через своих собственных знакомых. Результаты эксперимента показали, что в среднем письма достигали целевых лиц, используя примерно шесть промежуточных знакомых.

# %%
from IPython.display import Image
Image(filename='Desktop/7degree/qwe2.png')

# %% [markdown]
# Эксперимент Милгрэма был повторён учеными кафедры социологии Колумбийского университета при помощи электронной почты. Тысячам добровольцев они предложили «достучаться» до 20 засекреченных людей, о которых сообщали имя, фамилию, род занятий, место жительства, образование. Первой успешной попыткой стало определение почтового адреса одного из таких «засекреченных» в Сибири. Доброволец из Австралии нашёл адрес сибирской «цели» при помощи четырёх сообщений.
# Анализ экспертами Microsoft данных, полученных за месяц общения 242 720 596 пользователей, занял два года. Объём исследуемых данных составил около 4,5 ТБ. На этой информационной базе было установлено, что каждый из 240 миллионов пользователей сервиса мог бы «дойти» до другого в среднем за 6,6 «шага».
# Миланский университет и социальная сеть Facebook также провели совместное исследование теории шести рукопожатий, взяв за основу данные социального графа Facebook. Было установлено, что двух любых пользователей Facebook отделяет в среднем 3,74 уровня связи. Для США количество звеньев составило 4,37.
# На основе теории «тесного мира» возникло и множество популярных в США игр, например, учёные играют в «Число Эрдёша»
# С тех пор теория шести рукопожатий получила широкое распространение и стала активно исследоваться в различных сферах, включая социологию, психологию, информатику и даже математику. Было предложено несколько моделей и алгоритмов для анализа сетей и выявления связей между людьми.

# %% [markdown]
# ## Мысленный эксперимент

# %% [markdown]
# Давайте рассмотрим следующий мысленный эксперимент, чтобы продемонстрировать верность этой теории:
#
# Предположим, что у нас есть два человека: Алиса и Боб, которые живут в разных странах и никогда не встречались друг с другом. Цель состоит в том, чтобы установить связь между Алисой и Бобом через цепочку знакомых.
#
# Шаг 1: Алиса знает Дэйва, своего коллегу по работе.
#
# Шаг 2: Дэйв знаком с Клер, старым другом, с которым он учился в университете.
#
# Шаг 3: Клер знакома с Эриком, своим соседом по дому.
#
# Шаг 4: Эрик знаком с Фрэнком, своим тренером по футбольной команде.
#
# Шаг 5: Фрэнк знаком с Грейс, которая является сотрудницей местной библиотеки.
#
# Шаг 6: Грейс знакома с Бобом, так как он постоянно посещает библиотеку.
#
# Таким образом, мы построили цепочку знакомств, состоящую из шести человек, связывающую Алису и Боба:
#
# Алиса -> Дэйв -> Клер -> Эрик -> Фрэнк -> Грейс -> Боб
#
# Этот пример подтверждает верность теории шести рукопожатий. Хотя Алиса и Боб могут быть географически удалены друг от друга и никогда не встречались, они все равно могут быть связаны через цепочку знакомств, не превышающую шести человек.

# %%
from IPython.display import Image
Image(filename='Desktop/7degree/qwe3.png')

# %% [markdown]
# ## Теория шести рукопожатий на практике

# %% [markdown]
# Но какое же применение есть у такой, на первый взгряд, странной теории? Теория шести рукопожатий имеет множество практических значений и применений, которые не стоит недооценивать:
#
# Социальные сети: Теория шести рукопожатий помогает понять, как люди связаны друг с другом в социальных сетях. Это знание может быть использовано для разработки эффективных алгоритмов поиска, рекомендаций и анализа социальных связей.
#
# Сетевой анализ: Теория шести рукопожатий полезна в сетевом анализе, где исследуются взаимосвязи и взаимодействия между различными узлами в сложных сетях. Она может помочь в понимании глобальной структуры сетей, выявлении ключевых связей и определении кратчайших путей между узлами.
#
# Маркетинг и реклама: Использование теории шести рукопожатий может помочь в определении влиятельных личностей или целевых групп, а также в разработке стратегий маркетинга и рекламы, основанных на социальных связях и взаимодействии между людьми.
#
# Распространение информации и влияния: Теория шести рукопожатий может объяснить, как быстро и эффективно распространяется информация, идеи или влияние через общество. Это может быть полезно для дизайна кампаний информирования, пропаганды или политической мобилизации.
#
# Социальные исследования: В социологии, психологии и других областях науки теория шести рукопожатий используется для изучения социальных связей, социальной поддержки, доверия и других социальных явлений. Она помогает понять, как люди взаимодействуют и влияют друг на друга в социальной сети.
#
# Это лишь несколько примеров применения теории шести рукопожатий. Ее практическая значимость состоит в том, что она помогает нам лучше понять и оценить социальные связи, взаимодействия и структуру общества, а также использовать этот анализ для различных целей, начиная от социальных исследований до разработки стратегий маркетинга и коммуникации.

# %% [markdown]
# Какие же используются методы, используемых для решения задач, связанных с теорией шести рукопожатий и анализом социальных сетей? Некоторые из них включают в себя:
#
# Методы графовой теории: В рамках анализа социальных сетей, теория шести рукопожатий может быть формализована с помощью графовой теории. Граф представляет собой совокупность вершин (людей) и ребер (связи между ними). Различные алгоритмы графовой теории могут использоваться для нахождения кратчайших путей между двумя вершинами или для выявления важных узлов и сообществ в сети.
#
# Алгоритмы поиска: Методы поиска могут быть применены для поиска кратчайшего пути между двумя узлами в сети. Один из наиболее известных алгоритмов поиска кратчайшего пути - это алгоритм Дейкстры, который находит оптимальный путь во взвешенном графе. Этот алгоритм может быть применен для нахождения кратчайшего пути между двумя людьми в социальной сети.
#
# Алгоритмы машинного обучения: Методы машинного обучения могут быть использованы для анализа социальных сетей и предсказания связей между людьми. Например, алгоритмы классификации и кластеризации могут быть применены для выявления групп людей с схожими интересами или поведением, что помогает в построении более точных моделей теории шести рукопожатий.
#
# Социальные платформы и базы данных: Социальные платформы, такие как Facebook, LinkedIn и Twitter, предоставляют данные о связях между пользователями, которые могут быть использованы для анализа социальных сетей. Эти платформы обычно предоставляют API (интерфейс программирования приложений), позволяющие получать доступ к данным и строить алгоритмы анализа.
#
# Экспертные оценки и опросы: В некоторых случаях, особенно при изучении специфических социальных сетей или групп, могут использоваться экспертные оценки или опросы для сбора данных о связях между людьми. Это позволяет получить более точную информацию о связях, особенно в случаях, когда доступ к публичным данным ограничен или недоступен.
#
# Существует множество методов решения задач, связанных с теорией шести рукопожатий и анализом социальных сетей. Выбор конкретного метода зависит от конкретной задачи и доступных данных.

# %% [markdown]
# ## Реализация

# %%
# !pip install networkx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# ...

# %%
# Импортируем необходимые библиотеки
from typing import List
import networkx as nx
import requests

# Определяем класс для людей (Mr. Beast, please collab)
class Person:
    def __init__(self, name):
        self.name = name
        self.connections = []

    def add_connection(self, person):
        self.connections.append(person)


# Определяем класс приложения
class SixDegreesApp:
    def __init__(self):
        # граф находящийся внутри приложения из библиотеки networkx
        self.graph = nx.Graph()
        # счетчик считающий исключения в процессе выполнения программы (пользователь с приватным аккаунтом итд)
        self.exceptions = 0
        # словарь ключ которого состоит из строки связи людей(айдишников) ID1<->ID2, значение равно кол-ву рукопожатий  
        self.connections = {}
        # токен для работы с VK api
        self.token = '08f8682608f8682608f86826850bec68c4008f808f868266ca567b35dc8f37858cb4172'
        # версия VK api
        self.version = 5.92


    # Метод для добавления человека в граф
    def add_person(self, name):
        person = Person(name)
        self.graph.add_node(person)

    # Метод для добавления связи между двумя людьми в граф
    def add_connection(self, name1, name2):
        person1 = self.get_person(name1)
        person2 = self.get_person(name2)
        person1.add_connection(person2)
        person2.add_connection(person1)
        self.graph.add_edge(person1, person2)

    # Метод для получения объекта человека по его имени
    def get_person(self, name):
        for node in self.graph.nodes():
            if node.name == name:
                return node
        return None
    
    # метод который добавляет в словарь self.connections новые связи между человеком и списком людей(его друзей, полученных из vk api) 
    def update_amount(self, id1, ids : List):
        # ids будет private, когда api выдаст ошибку получения друзей пользователя из-за приватного аккаунта
        if ids != 'private':
            self.add_person(id1)
            for id2 in ids:
                self.add_person(id2)
                self.add_connection(id1, id2)
                self.connections[f'{id1}<->{id2}'] = 1
                self.connections[f'{id2}<->{id1}'] = 1
            

    # Метод для поиска длины кратчайшего пути между двумя людьми в графе
    # print_path - для печати пути по нодам
    def shortest_path(self, name1, name2, print_path=False):
        # берем двух людей из графа по значению имени(ID)
        person1 = self.get_person(name1)
        person2 = self.get_person(name2)

        try:
            if f'{name1}<->{name2}' not in self.connections:
                distance = nx.shortest_path_length(self.graph, person1, person2)
                if distance != 0:
                    self.connections[f'{name1}<->{name2}'] = distance
                    self.connections[f'{name2}<->{name1}'] = distance
                    return distance
            else:
                if print_path:
                    path = nx.shortest_path(self.graph, person1, person2)
                    path = [x.name for x in path]
                    print(path)
                return self.connections[f'{name1}<->{name2}']

        # если невозможно найти связь между людьми это идет в исключения
        except nx.exception.NetworkXNoPath:
            print(f'связи между {name1} и {name2} не существует')
            self.exceptions += 1


    # метод для получения ответа от VK api с помощью бибилиотеки request для польвателя с именем first_id
    def create_response(self, first_id):
        return requests.get('https://api.vk.com/method/friends.get',
                                params={
                                    'access_token' : self.token,
                                    'v' : self.version,
                                    'user_id' : first_id
                                })
    

    # метод для получения списка друзей(ID-шников) пользователя с именем first_id
    def get_data_from_response(self, first_id):
        response = self.create_response(first_id)
        try:
            data = response.json()['response']['items']
            print(f'пользователь ID{first_id} имеет {len(data)} друзей // using get_data_from_response')
            return data
        except:
            return 'private'


    # метод для получения среднего кол-ва рукопожатий между всеми добавленными пользователями
    def get_average(self):
        return sum(self.connections.values()) / len(self.connections)
                    

    # Алгоритм подразумевает прохождение каждого пользоваетя по каждому пользователю и добавление связи между ними, если таковая имеется
    # сложность O(n^2) - в худшем варианте 
    # оптимизация: при добавлениях пользователей см метод update_amount мы добавляем в словарь connections
    # связи между пользователями. При выполнении алгоритма мы смотрим есть ли в словаре уже такая запись
    # в конце программы мы получаем полностью заполненный всеми связями в графе словарь, значения которого 
    # явл-ся количесвтом рукопожатий между пользователями.
    def process_app(self):
        for node1 in self.graph.nodes:
            for node2 in self.graph.nodes:
                key_nodes1 = f'{node1.name}<->{node2.name}'
                key_nodes2 = f'{node2.name}<->{node1.name}'
                if key_nodes1 not in self.connections and key_nodes2 not in self.connections and node1.name != node2.name:
                    self.shortest_path(node1.name, node2.name) 


    # метод, позваоляющий запустить приложение. Он принимает ID первого произвольного пользователя, 
    # добавляет в приложение список его друзей и работает с ними
    # complexity - параметр сложности. позволяет взять меньшее кол-во друзей человека first_id для 
    # быстрого и наглядного выполнения программы
    def simple_run(self, first_id, complexity=382):

        data = self.get_data_from_response(first_id)
        self.update_amount(first_id, data)

        for i in range(len(data) - complexity):
            new_id = data[i]
            new_data = self.get_data_from_response(new_id)
            self.update_amount(new_id, new_data)
        self.process_app()

# объявляем корень приложения, ID, с которого начнется создание графа и получения его друзей в VK
FIRST_ID = 155632877
FRIEND_ID = 697434996
ANOTHER_ID = 269206327

# Создаем экземпляр приложения
app = SixDegreesApp()

# Запуск приложения
app.simple_run(FIRST_ID, complexity=382)

# Информация о выполненной программе 
print(f'добавлено {len(app.connections)} записей в словарь connections')
print(f'граф состоит из {len(app.graph.nodes)} Нод')

print(f'Среднее кол-во рукопожатий {round(app.get_average(), 3)}, исключений встречено: {app.exceptions}')
print(f'путь между ID{ANOTHER_ID} и ID{FRIEND_ID} : {app.shortest_path(ANOTHER_ID, FRIEND_ID, print_path=True)}')

# Консоль
# пользователь ID155632877 имеет 383 друзей // using get_data_from_response
# пользователь ID971333 имеет 919 друзей // using get_data_from_response
# добавлено 1660232 записей в словарь connections
# граф состоит из 1304 Нод
# Среднее кол-во рукопожатий 2.401, исключений встречено: 0
# [269206327, 155632877, 697434996]
# путь между ID155632877 и ID697434996 : 2

# наш вывод в том, что словарь хорошая идея, но для него на каждую запись связи 
# нужно добавлять две записи ака ID_1<->ID_2 и ID_2<->ID_1
# Out:
# пользователь ID155632877 имеет 383 друзей // using get_data_from_response
# пользователь ID971333 имеет 919 друзей // using get_data_from_response
# добавлено 1660232 записей в словарь connections
# граф состоит из 1304 Нод
# Среднее кол-во рукопожатий 2.401, исключений встречено: 0
# [269206327, 155632877, 697434996]
# путь между ID269206327 и ID697434996 : 2

# %% [markdown]
# ## ---
