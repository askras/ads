# %% [markdown]
# # Проект: "Вычисление числа Эйлера"

# %% [markdown]
# **Подготовили студенты ИУ10-46:**
#
# | Вариант | ФИО | Выполняемые пункты работы |
# |:---|:---|:---|
# | 10  | Кузнецов Денис | 2, 3, 5 |
# | 12  | Мартьянова Алиса | 4, 6, 8 |
# | 14  | Поддоскина Светлана | 1, 7, 9 |

# %% [markdown]
# **Задачи проекта:**
# 1. Ознакомиться с теоретическим содержанием задачи(историей возникновения, существующими методами решения, практической значимостью и т.д.).
# 2. Разработать и реализовать структуру данных для хранения десятичных знаков числа $e$
# 3. Реализовать алгоритм(ы) вычисления десятичных знаков числа $e$
# 4. Сравнить эффективность (точность) существующих алгоритмов.
# 5. Вычислить первые N (N постараться сделать N как можно больше) десятичных знаков числа $e$
# 6. Проверить гипотезу о том, что в числе $e$ можно найти любую информацию. Например, найти дату своего рождения, текущую дату, кличку домашнего питомца (при наличии). При поиске текстовой информации разработать способ ее числового кодирования.
# 7. Проверить гипотезу о практичности использования числа $e$ в качестве универсального архиватора. Идея заключается в хранении не самих данных, а номера позиции, в которой эти данные вствречаются в десятичной записи числа $e$ и длины данных.
# 8. Провести анализ эффективности используемых структур данных и алгоритмов.
# 9. Подготовить отчет о проделанной работе.

# %% [markdown]
# ## 1. Теоретические сведения

# %% [markdown]
# **Общие сведения**
#
# $e$ — основание натурального логарифма, математическая константа, иррациональное и трансцендентное число. Приблизительно равно 2,71828. Иногда число $e$ называют числом Эйлера или числом Непера. Число $e$ играет важную роль в дифференциальном и интегральном исчислении, а также во многих других разделах математики.
#
# Число Эйлера можно записать так: 2,7182818284 5904523536 0287471352 6624977572 4709369995 9574966967 6277240766 3035354759 4571382178 5251664274 2746639193 2003059921 8174135966 2904357290 0334295260 5956307381 3232862794 3490763233 8298807531 9525101901 1573834187 9307021540 8914993488 4167509244 7614606680 8226480016 8477411853 7423454424 3710753907 7744992069 5517027618 3860626133 1384583000 7520449338 2656029760 6737113200 7093287091 2744374704 7230696977 2093101416 9283681902 5515108657 4637721112 5238978442 5056953696 7707854499 6996794686 4454905987 9316368892 3009879312 7736178215 4249992295 7635148220 8269895193 6680331825 2886939849 6465105820 9392398294 8879332036 2509443117 3012381970 6841614039 7019837679 3206832823 7646480429 5311802328 7825098194 5581530175 6717361332 0698112509 9618188159 3041690351 5988885193 4580727386 6738589422 8792284998 9208680582 5749279610 4841984443 6346324496 8487560233 6248270419 7862320900 2160990235 3043699418 4914631409 3431738143 6405462531 5209618369 0888707016 7683964243 7814059271 4563549061 3031072085 1038375051 0115747704 1718986106 8739696552 1267154688 9570350354…
#
# **Вычисление числа e**
#
# Число $e$ может быть определено несколькими способами.
#
# 1. Через предел:
#
# $e=\lim _{x\to \infty }\left(1+{\frac {1}{x}}\right)^{x}$ (второй замечательный предел).
#
# ${\displaystyle e=\lim _{n\to \infty }{\frac {n}{\sqrt[{n}]{n!}}}}$ (это следует из формулы Муавра — Стирлинга).
#
# 2. Как сумма ряда:
#
# $e=\sum _{n=0}^{\infty }{\frac {1}{n!}}$ или ${\frac {1}{e}}=\sum _{n=2}^{\infty }{\frac {(-1)^{n}}{n!}}$
#
# 3. Как единственное положительное число a, для которого выполняется:
#
# ${\displaystyle \int \limits _{1}^{a}{\frac {dx}{x}}=1}$ и ${\displaystyle {\frac {d}{dx}}a^{x}=a^{x}.}$
#
# **История возникновения**
#
# Число появилось сравнительно недавно. Данное число иногда называют неперовым в честь шотландского учёного Джона Непера (1550-1617), автора работы "Описание удивительной таблицы логарифмов" (1614 год). Но это название не совсем корректно, так как у него логарифм числа x был равен: ${\displaystyle 10^{7}\cdot \,\log _{1/e}\left({\frac {x}{10^{7}}}\right)}$. Нет твёрдых оснований для утверждения, что Непер имел о числе $e$ чёткое представление
#
# Впервые обозначение "$e$" ввёл Леонард Эйлер (1707-1783). Он также вычислил точные 23 десятичные знака этого числа, использовав представление числа $e$ в виде бесконечного числового ряда.
#
# Встречаясь буквально на каждом шагу в высшей математике, в особенности в задачах теории вероятностей, в реальной жизни оно проявляет себя ярче всего при росте какой – либо величины, будь то рост клетки или банковского счета.
#
# **Применение числа e в физике и математике**
#
# Число e широко используется в физике и математике, поскольку оно фигурирует в различных математических формулах и моделях. Вот некоторые из его применений:
#
# 1. *Экспоненциальные функции*. В математике e является основанием натурального логарифма и используется для определения экспоненциальных функций. Показательная функция — одно из важнейших математических понятий, которое широко используется в различных областях науки, в том числе и в физике.
#
# 2. *Непрерывные сложные проценты*. В финансах буква «e» используется для расчета непрерывных сложных процентов, когда процентная ставка непрерывно начисляется с течением времени. В этой модели сумма процентов растет экспоненциально со временем.
#
# 3. *Дифференциальные уравнения* — e используется при решении дифференциальных уравнений, которые описывают, как величина изменяется во времени. Многие физические и биологические процессы описываются дифференциальными уравнениями, и e часто фигурирует в этих уравнениях как константа.
#
# 4. *Теория вероятностей* — e используется в теории вероятностей, где оно фигурирует в различных формулах, описывающих распределение вероятностей событий во времени. Например, экспоненциальное распределение, широко используемое в технике надежности, основано на e.
#
# 5. *Квантовая механика* — e также появляется в квантовой механике, где оно используется при решении уравнения Шрёдингера, описывающего поведение частиц на квантовом уровне. В квантовой механике e используется для описания экспоненциального роста или распада квантовых состояний с течением времени.
#
# 6. В *физике* число e появляется в задачах экспоненциального распада и роста, где оно представляет собой основание натурального логарифма. Он также используется для расчета непрерывно начисляемых процентов, а также времени, необходимого для увеличения количества на определенный коэффициент.
#
# В математике e — это константа, которая появляется во многих математических уравнениях, включая показательную функцию и логарифмические функции. Он также используется в исчислении, где появляется в формуле производной экспоненциальной функции. Кроме того, e используется в тригонометрии для нахождения значений экспоненциальных и логарифмических функций.
#
# Таким образом, e — это универсальная и важная математическая константа, имеющая многочисленные применения в физике, математике, финансах и других областях науки.
#
# **Применение числа e в финансах**
#
# Число e широко используется в финансах для финансовых расчетов. Одним из наиболее распространенных применений е в финансах является расчет сложных процентов. Сложные проценты — это термин, который относится к процентам по кредиту или депозиту, рассчитываемым на основе как первоначально основной суммы, так и накопленных процентов.
#
# Формулу сложных процентов можно представить следующим образом: $A = P * (1 + r/n)^{nt}$,
#
# где A — конечная сумма, P — первоначальная основная сумма, r — процентная ставка, n — количество начислений процентов в год, t — количество лет.
#
# Математическая константа e используется для представления числа, на которое начисляются проценты в год, а экспоненциальная функция позволяет нам рассчитать конечную сумму.
#
# В дополнение к этим приложениям e также используется в расчетах аннуитетов, бессрочных и непредвиденных обстоятельств жизни. В целом число e играет жизненно важную роль в различных финансовых расчетах и ​​моделях, обеспечивая последовательное и точное представление экспоненциального роста и стоимости денег во времени.

# %% [markdown]
# ## 2. Cтруктура данных для хранения десятичных знаков числа $e$

# %% [markdown]
# Структура данных для хранения - decimal и str

# %%
import decimal
import sys
import psutil

sys.set_int_max_str_digits(100000)
real_e = decimal.Decimal('2....')


class EulerNum:
    def __init__(self, precision_given: int):
        decimal.getcontext().prec = precision_given + 3
        if precision_given == 0:
            self.num = str(3)
            return
        precision_real = decimal.Decimal('1e-' + str(precision_given))
        euler = decimal.Decimal(str(2.0))
        factorial = 1
        tmp = decimal.Decimal(str(1.0))
        index = 2
        while tmp > precision_real:
            factorial *= index
            tmp = decimal.Decimal(str(1.0)) / decimal.Decimal(str(factorial))
            euler += tmp
            index += 1
        self.num = (round(euler, precision_given))

    def __str__(self):
        return str(self.num)

    def __repr__(self):
        return str(self.num)


e = EulerNum(10000)

print(e)

print("Текущая загрузка ЦП в масштабе всей системы в %:", psutil.cpu_percent())
# Out:
# 2....
# Текущая загрузка ЦП в масштабе всей системы в %: 12.5

# %% [markdown]
# ## 3. Алгоритм вычисления десятичных знаков числа $e$

# %%
import decimal
import sys

sys.set_int_max_str_digits(100000)
real_e = decimal.Decimal('2....')


class EulerNum:
    def __init__(self, precision_given: int):
        decimal.getcontext().prec = precision_given + 3
        if precision_given == 0:
            self.num = str(3)
            return
        precision_real = decimal.Decimal('1e-' + str(precision_given))
        euler = decimal.Decimal(str(2.0))
        factorial = 1
        tmp = decimal.Decimal(str(1.0))
        index = 2
        while tmp > precision_real:
            factorial *= index
            tmp = decimal.Decimal(str(1.0)) / decimal.Decimal(str(factorial))
            euler += tmp
            index += 1
        self.num = (round(euler, precision_given))

    def __str__(self):  # Для возможности использовать print()
        return str(self.num)

    def __repr__(self):  # Для возможности выводить
        return str(self.num)

N = int(input())
e = EulerNum(N)

print(e)
# Out:
# 100
# 2.7182818284590452353602874713526624977572470936999595749669676277240766303535475945713821785251664274

# %% [markdown]
# ## 4. Сравнение эффективность существующих алгоритмов

# %% [markdown]
# Пример того, что классические виды измерения, вроде %time, не работают для данных вычислений

# %%
# 1
import decimal
import sys
import timeit
# %time


sys.set_int_max_str_digits(100000)
real_e = decimal.Decimal('2....')


class EulerNum:
    def __init__(self, precision_given: int):
        decimal.getcontext().prec = precision_given + 3
        if precision_given == 0:
            self.num = str(3)
            return
        precision_real = decimal.Decimal('1e-' + str(precision_given))
        euler = decimal.Decimal(str(2.0))
        factorial = 1
        tmp = decimal.Decimal(str(1.0))
        index = 2
        while tmp > precision_real:
            factorial *= index
            tmp = decimal.Decimal(str(1.0)) / decimal.Decimal(str(factorial))
            euler += tmp
            index += 1
        self.num = (round(euler, precision_given))

    def __str__(self):
        return str(self.num)

    def __repr__(self):
        return str(self.num)
    

execution_time = timeit.timeit(lambda: EulerNum(1000), number=1)

e = EulerNum(1000)

print(e)

print("Время выполнения:", execution_time, "секунд")
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 2....
# Время выполнения: 0.018447899994498584 секунд

# %% [markdown]
# Использовали библиотеку psutil и функцию psutil.cpu_percent() для вычисления загрузки ЦП. Ещё сравнили по времени с помощью timeit

# %%
# 2
import decimal
import sys
import timeit
import psutil

sys.set_int_max_str_digits(100000)
real_e = decimal.Decimal('2....')


class EulerNum:
    def __init__(self, precision_given: int):
        decimal.getcontext().prec = precision_given + 3
        if precision_given == 0:
            self.num = str(3)
            return
        precision_real = decimal.Decimal('1e-' + str(precision_given))
        euler = decimal.Decimal(str(2.0))
        factorial = 1
        tmp = decimal.Decimal(str(1.0))
        index = 2
        while tmp > precision_real:
            factorial *= index
            tmp = decimal.Decimal(str(1.0)) / decimal.Decimal(str(factorial))
            euler += tmp
            index += 1
        self.num = (round(euler, precision_given))

    def __str__(self):
        return str(self.num)

    def __repr__(self):
        return str(self.num)
    

execution_time = timeit.timeit(lambda: EulerNum(1000), number=1)

e = EulerNum(1000)

print(e)

print("Время выполнения:", execution_time, "секунд")

print("Текущая загрузка ЦП в масштабе всей системы в %:", psutil.cpu_percent())
# Out:
# 2....
# Время выполнения: 0.02028499999869382 секунд
# Текущая загрузка ЦП в масштабе всей системы в %: 5.4

# %%
# 3
import numpy as np
from decimal import Decimal, getcontext
import time
import psutil

getcontext().prec = 1000

n = 1000

start_time = time.time() 

e = sum(Decimal(1) / Decimal(np.math.factorial(i)) for i in range(n))

end_time = time.time()

time = end_time - start_time

print(e)
print("Время выполнения:", time, "секунд")
print("Текущая загрузка ЦП в масштабе всей системы в %:", psutil.cpu_percent())
# Out:
# 2....
# Время выполнения: 0.13438105583190918 секунд
# Текущая загрузка ЦП в масштабе всей системы в %: 5.5

# %% [markdown]
# Число Эйлера в данном модуле - математическая константа. Поэтому вывод ЦП в % делается уже после вывода значения в терминале.

# %%
# 4
import time
import mpmath
import psutil

mpmath.mp.dps = 10000

start_time = time.time()
e = mpmath.e

print("Число Эйлера:", e)

end_time = time.time()

print("Время выполнения:", "{:.10f}".format(end_time - start_time), "секунд")

print("Текущая загрузка ЦП в масштабе всей системы в %:", psutil.cpu_percent())
# Out:
# Число Эйлера: 2....
# Время выполнения: 0.0040001869 секунд
# Текущая загрузка ЦП в масштабе всей системы в %: 8.4

# %% [markdown]
# То же самое предположение о константе

# %%
# 5
import warnings
warnings.filterwarnings('ignore')

import time
import scipy
import psutil

scipy.set_printoptions(precision=1000)

start_time = time.time()

e = scipy.exp(1)

print("Число Эйлера:", e)

end_time = time.time()

print("Время выполнения:", "{:.10f}".format(end_time - start_time), "секунд")

print("Текущая загрузка ЦП в масштабе всей системы в %:", psutil.cpu_percent())
# Out:
# Число Эйлера: 2.718281828459045
# Время выполнения: 0.0000000000 секунд
# Текущая загрузка ЦП в масштабе всей системы в %: 15.5

# %% [markdown]
# ## 5. Вычисление первых N десятичных знаков числа $e$

# %% [markdown]
# N = 10000

# %%
import decimal
import sys
import psutil

class EulerNum:
    def __init__(self, precision_given: int):
        decimal.getcontext().prec = precision_given + 3
        if precision_given == 0:
            self.num = str(3)
            return
        precision_real = decimal.Decimal('1e-' + str(precision_given))
        euler = decimal.Decimal(str(2.0))
        factorial = 1
        tmp = decimal.Decimal(str(1.0))
        index = 2
        while tmp > precision_real:
            factorial *= index
            tmp = decimal.Decimal(str(1.0)) / decimal.Decimal(str(factorial))
            euler += tmp
            index += 1
        self.num = (round(euler, precision_given))

    def __str__(self):
        return str(self.num)

    def __repr__(self):
        return str(self.num)


e = EulerNum(10000)

print(e)
# Out:
# 2....

# %% [markdown]
# ## 6. Проверка гипотезы №1
# **Гипотеза №1:** в числе $e$ можно найти любую информацию.

# %% [markdown]
# Проверка того, что в числе можно найти любую дату или имя собаки в двоичном коде, - не подтвердилась. Число Эйлера является иррациональным и не имеет периодической структуры, в его десятичном представлении невозможно найти какие-либо паттерны. Либо же проведено недостаточное количество вычислений, в силу отсутствия необходимых для эксперимента мощностей.

# %%
import decimal
import sys
import math
import psutil

sys.set_int_max_str_digits(100000)
real_e = decimal.Decimal('2....')


class EulerNum:
    def __init__(self, precision_given: int):
        decimal.getcontext().prec = precision_given + 3
        if precision_given == 0:
            self.num = str(3)
            return
        precision_real = decimal.Decimal('1e-' + str(precision_given))
        euler = decimal.Decimal(str(2.0))
        factorial = 1
        tmp = decimal.Decimal(str(1.0))
        index = 2
        while tmp > precision_real:
            factorial *= index
            tmp = decimal.Decimal(str(1.0)) / decimal.Decimal(str(factorial))
            euler += tmp
            index += 1
        self.num = (round(euler, precision_given))

    def __str__(self):
        return str(self.num)

    def __repr__(self):
        return str(self.num)


e = EulerNum(2000)

print(e)

def find(target_info):
    euler = str(e)
    if target_info in euler:
        return True
    else:
        return False

def encode_text_to_number(text):
    encoded_number = 0
    for char in text:
        encoded_number = encoded_number * 10 + ord(char)
    return encoded_number

result_1 = find("1411")
result_2 = find("1802")

name = "Песик"
encoded_name = encode_text_to_number(name)

result_3 = find(str(encoded_name))

print("Найдена ли дата рождения в числе Эйлера (2000 знаков):", result_1)
print("Найдена ли текущая дата в числе Эйлера (2000 знаков):", result_2)
print("Кличка домашнего питомца:", name)
print("Закодированное число:", encoded_name)
print("Найдена ли закодированное число в числе Эйлера (2000 знаков):", result_3)
print("Текущая загрузка ЦП в масштабе всей системы в %:", psutil.cpu_percent())
# Out:
# 2....
# Найдена ли дата рождения в числе Эйлера (2000 знаков): False
# Найдена ли текущая дата в числе Эйлера (2000 знаков): True
# Кличка домашнего питомца: Песик
# Закодированное число: 11747782
# Найдена ли закодированное число в числе Эйлера (2000 знаков): False
# Текущая загрузка ЦП в масштабе всей системы в %: 5.0

# %% [markdown]
# ## 7. Проверика гипотезы №2
# **Гипотеза №2:** практичность использования числа $e$ в качестве универсального архиватора.

# %% [markdown]
# Принцип работы архиватора Е:
#
# 1. Есть искомое сообщение, каждый символ которого мы переводим в десятичное представление по таблице ascii;
#
# 2. Далее находим его в числе Эйлера (на этом этапе проверяем, возможно ли его здесь найти);
#
# 3. Запоминаем номер позиции, с которого наше сообщение совпадает с фрагментом числа Эйлера, и длину сообщения в десятичной системе счисления.
#
# Однако исходя из прошлого примера, мы получили результат: не все числовые комбинации мы можем найти в числе Эйлера. Следовательно, данный алгоритм неэффективен в качестве универсального архиватора.
#
# Рассмотрим пример, когда данный алгоритм находит комбинацию нашего сообщения в числе Эйлера, и сравним работу по времени с архиватором питона, и рассмотрим второй пример, когда программа просто не смогла найти искомое сообщение в числе Эйлера

# %%
example_1 = '@/['
num_1 = ''

for i in example_1:
    need = ord(i)
    num_1 = num_1 + str(need) 

print(num_1)
# Out:
# 644791

# %%
example_2 = 'ab_268@qeu a'
num_2 = ''

for i in example_2:
    need = ord(i)
    num_2 = num_2 + str(need)

print(num_2)
# Out:
# 979895505456641131011173297

# %%
example_3 = 'À`<I{]L#*'
num_3 = ''

for i in example_3:
    need = ord(i)
    num_3 = num_3 + str(need)

print(num_3)
# Out:
# 19296607312393763542

# %%
import decimal
import sys
import math
import psutil

sys.set_int_max_str_digits(100000)
real_e = decimal.Decimal('2....')


class EulerNum:
    def __init__(self, precision_given: int):
        decimal.getcontext().prec = precision_given + 3
        if precision_given == 0:
            self.num = str(3)
            return
        precision_real = decimal.Decimal('1e-' + str(precision_given))
        euler = decimal.Decimal(str(2.0))
        factorial = 1
        tmp = decimal.Decimal(str(1.0))
        index = 2
        while tmp > precision_real:
            factorial *= index
            tmp = decimal.Decimal(str(1.0)) / decimal.Decimal(str(factorial))
            euler += tmp
            index += 1
        self.num = (round(euler, precision_given))

    def __str__(self):
        return str(self.num)

    def __repr__(self):
        return str(self.num)

e = EulerNum(10000)
# print(e)

def find(target_info):
    euler = str(e)
    if target_info in euler:  
        return "Найдена в числе Эйлера", euler.find(target_info), len(target_info) # выводит позицию и длину данных в десятичной системе счисления
    else:
        return "Не найдена в числе Эйлера"

    
euler = str(e)
result_1 = find(num_1)
result_2 = find(num_2)
# result_3 = find(num_3)
print("Искомая комбинация примера 1 :", result_1)
print("Искомая комбинация примера 2 :", result_2)
# print("Искомая комбинация примера 3 :", result_3)
# Out:
# Искомая комбинация примера 1 : ('Найдена в числе Эйлера', 1480, 6)
# Искомая комбинация примера 2 : Не найдена в числе Эйлера

# %% [markdown]
# Сравним по времени с обычным архиватором:

# %%
import time

start_time = time.time()

result_3 = find(num_3)

end_time = time.time()

print("Искомая комбинация примера 3 :", result_3)
print("Time:", end_time - start_time)
# Out:
# Искомая комбинация примера 3 : ('Найдена в числе Эйлера', 8407, 20)
# Time: 0.0

# %%
import zlib
import time

start_time = time.time()

cmpstr = zlib.compress(example_3.encode('utf-8'))

end_time = time.time()

print(len(cmpstr))
print("Time:", end_time - start_time)
# Out:
# 18
# Time: 0.0

# %% [markdown]
# ## 8. Анализ эффективности используемых структур данных и алгоритмов.

# %% [markdown]
# Сравнительный анализ метрик текущей загрузки ЦП в масштабе всей системы в %

# %% [markdown]
# |   1  |   2  |  3   |  4   |   5  |   6  |
# |------|------|------|------|------|------|
# |  2.5 |  5.3 |  5.2 |  5.5 |  5.0 |  5.6 |

# %% [markdown]
# На самом деле таблица только приблизительная, так как время обработки может отличаться на 1.5-2 % и зависит не только от самого кода, но и от общих характеритик системы. Т.е. у кого-то будет быстрее, у кого-то медленнее

# %% [markdown]
# # Используемые источники

# %% [markdown]
# 1. https://ru.wikipedia.org/wiki/E_(%D1%87%D0%B8%D1%81%D0%BB%D0%BE) - Википедия
# 2. https://schetuchet.ru/chislo-e-svojstva-i-sfera-primeneniya/?ysclid=lhxo7tfmut989933683
